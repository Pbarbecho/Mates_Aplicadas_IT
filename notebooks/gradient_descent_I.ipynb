# %%
import numpy as np
import matplotlib.pyplot as plt



# Definimos la funciÃ³n (funciÃ³n objetiva)
def f(x):
    return x ** 2  # np.sin(x)


# Definimos la derivada parcial respecto a x
def df_dx(x):
    return 2 * x  # np.cos(x)


# interactive plot
def plot_f(current_pos):
    # Plot function
    x = np.arange(-50, 50, 0.1)  # dominio
    y = f(x)
    plt.plot(x, y)
    plt.scatter(current_pos[0], current_pos[1], color='red')
    #plt.pause(0.5)
    #plt.clf()


def gradient_descen(iter, learing_rate, current_pos, break_iter):
    for i in range(iter):
        # gradient descent
        new_x = current_pos[0] - learing_rate * df_dx(current_pos[0])
        print(f'Iteraciones:{i} , Pendiente: {df_dx(current_pos[0])}')
        new_y = f(new_x)
        current_pos = (new_x, new_y)
        plot_f(current_pos)
        if df_dx(current_pos[0]) < 10e-10:
            if new_x < 0.00001:
                break

iter = 100  # Iteraciones
learing_rate = 0.2  # tasa de aprendizaje
current_pos = (50, f(50))  # Random Point
break_iter = True

# method
gradient_descen(iter, learing_rate, current_pos, break_iter)
# Out:
# Iteraciones:0 , Pendiente: 100
# <img src="data:image/png;base64,..." width="640">
# Iteraciones:1 , Pendiente: 60.0
# Iteraciones:2 , Pendiente: 36.0
# Iteraciones:3 , Pendiente: 21.6
# Iteraciones:4 , Pendiente: 12.96
# Iteraciones:5 , Pendiente: 7.776
# Iteraciones:6 , Pendiente: 4.6655999999999995
# Iteraciones:7 , Pendiente: 2.7993599999999996
# Iteraciones:8 , Pendiente: 1.6796159999999998
# Iteraciones:9 , Pendiente: 1.0077695999999998
# Iteraciones:10 , Pendiente: 0.6046617599999999
# Iteraciones:11 , Pendiente: 0.36279705599999995
# Iteraciones:12 , Pendiente: 0.21767823359999997
# Iteraciones:13 , Pendiente: 0.13060694015999996
# Iteraciones:14 , Pendiente: 0.07836416409599997
# Iteraciones:15 , Pendiente: 0.047018498457599985
# Iteraciones:16 , Pendiente: 0.02821109907455999
# Iteraciones:17 , Pendiente: 0.016926659444735995
# Iteraciones:18 , Pendiente: 0.010155995666841597
# Iteraciones:19 , Pendiente: 0.006093597400104958
# ...
