# %%
import numpy as np
import matplotlib.pyplot as plt

#Definimos la funciÃ³n (funciÃ³n objetiva)
def f(x):
    return np.sin(x)

# Definimos la derivada parcial respecto a x
def df_dx(x):
    return np.cos(x)

# interactive plot
def plot_f(current_pos):
    # Plot function
    x = np.arange(-5, 5, 0.1)
    y = f(x)
    plt.plot(x, y)
    plt.scatter(current_pos[0], current_pos[1], color='red')
   

def gradient_descen(iter, learing_rate, current_pos, break_iter):
    for i in range(iter):
        # gradient descent algorithm
        new_x = current_pos[0] - learing_rate * df_dx(current_pos[0])
        print(f'Iteraciones:{i} , Pendiente: {df_dx(current_pos[0])}')
        new_y = f(new_x)
        current_pos = (new_x, new_y)
        plot_f(current_pos)
        if break_iter:
            if df_dx(current_pos[0]) < 10e-10:
                break


iter = 1000  # Iteraciones
learing_rate = 0.1  # tasa de aprendizaje
current_pos = (0.8, f(0.8))  # Random Point
break_iter = True

# method
gradient_descen(iter, learing_rate, current_pos, break_iter)
# Out:
# Iteraciones:0 , Pendiente: 0.6967067093471655
# <img src="data:image/png;base64,..." width="640">
# Iteraciones:1 , Pendiente: 0.744954742385353
# Iteraciones:2 , Pendiente: 0.7925397020766183
# Iteraciones:3 , Pendiente: 0.8383320592303263
# Iteraciones:4 , Pendiente: 0.8810368738695916
# Iteraciones:5 , Pendiente: 0.919243006712427
# Iteraciones:6 , Pendiente: 0.9515006913692027
# Iteraciones:7 , Pendiente: 0.9764251630642972
# Iteraciones:8 , Pendiente: 0.9928174792535445
# Iteraciones:9 , Pendiente: 0.9997869128245926
# Iteraciones:10 , Pendiente: 0.9968546819453077
# Iteraciones:11 , Pendiente: 0.9840187045201965
# Iteraciones:12 , Pendiente: 0.9617647784087177
# Iteraciones:13 , Pendiente: 0.9310201663973614
# Iteraciones:14 , Pendiente: 0.893057880436124
# Iteraciones:15 , Pendiente: 0.8493699289881087
# Iteraciones:16 , Pendiente: 0.8015322770790666
# Iteraciones:17 , Pendiente: 0.7510824760860586
# Iteraciones:18 , Pendiente: 0.699424464290158
# Iteraciones:19 , Pendiente: 0.6477668121020188
# Iteraciones:20 , Pendiente: 0.5970933905033687
# Iteraciones:21 , Pendiente: 0.5481606381721195
# Iteraciones:22 , Pendiente: 0.5015135645048704
# Iteraciones:23 , Pendiente: 0.45751275438365163
# Iteraciones:24 , Pendiente: 0.4163660267785807
# Iteraciones:25 , Pendiente: 0.37816023076131583
# Iteraciones:26 , Pendiente: 0.3428904007219271
# Iteraciones:27 , Pendiente: 0.3104848759283633
# Iteraciones:28 , Pendiente: 0.28082595547646805
# Iteraciones:29 , Pendiente: 0.2537662553303373
# Iteraciones:30 , Pendiente: 0.22914124857029783
# Iteraciones:31 , Pendiente: 0.20677859395702525
# Iteraciones:32 , Pendiente: 0.18650486606511935
# Iteraciones:33 , Pendiente: 0.1681502464018336
# Iteraciones:34 , Pendiente: 0.15155165437446572
# Iteraciones:35 , Pendiente: 0.13655471075684925
# Iteraciones:36 , Pendiente: 0.12301484569112014
# Iteraciones:37 , Pendiente: 0.11079779329253743
# Iteraciones:38 , Pendiente: 0.09977965701239336
# Iteraciones:39 , Pendiente: 0.08984668353278248
# Iteraciones:40 , Pendiente: 0.08089484671011302
# Iteraciones:41 , Pendiente: 0.07282931526589136
# Iteraciones:42 , Pendiente: 0.0655638568978745
# Iteraciones:43 , Pendiente: 0.05902021579348566
# Iteraciones:44 , Pendiente: 0.0531274889482254
# Iteraciones:45 , Pendiente: 0.04782151823736444
# Iteraciones:46 , Pendiente: 0.043044309082002144
# Iteraciones:47 , Pendiente: 0.0387434821896765
# Iteraciones:48 , Pendiente: 0.03487176177710368
# Iteraciones:49 , Pendiente: 0.03138650155306807
# Iteraciones:50 , Pendiente: 0.028249248295023604
# Iteraciones:51 , Pendiente: 0.02542534190227391
# Iteraciones:52 , Pendiente: 0.02288355021069798
# Iteraciones:53 , Pendiente: 0.02059573650555033
# Iteraciones:54 , Pendiente: 0.018536557494620156
# Iteraciones:55 , Pendiente: 0.016683189449443064
# Iteraciones:56 , Pendiente: 0.015015080248007778
# Iteraciones:57 , Pendiente: 0.013513725130408931
# Iteraciones:58 , Pendiente: 0.01216246408918895
# Iteraciones:59 , Pendiente: 0.010946298944686482
# Iteraciones:60 , Pendiente: 0.00985172829283888
# Iteraciones:61 , Pendiente: 0.008866598651934635
# Iteraciones:62 , Pendiente: 0.007979970271370188
# Iteraciones:63 , Pendiente: 0.00718199619670518
# Iteraciones:64 , Pendiente: 0.006463813309491449
# Iteraciones:65 , Pendiente: 0.00581744417656515
# Iteraciones:66 , Pendiente: 0.005235708651303788
# Iteraciones:67 , Pendiente: 0.004712144268751133
# Iteraciones:68 , Pendiente: 0.00424093456768796
# Iteraciones:69 , Pendiente: 0.0038168445560435777
# Iteraciones:70 , Pendiente: 0.0034351626119393003
# Iteraciones:71 , Pendiente: 0.0030916481816314987
# Iteraciones:72 , Pendiente: 0.002782484698185853
# Iteraciones:73 , Pendiente: 0.002504237201377389
# Iteraciones:74 , Pendiente: 0.0022538141905645175
# Iteraciones:75 , Pendiente: 0.002028433288606175
# Iteraciones:76 , Pendiente: 0.001825590336710348
# Iteraciones:77 , Pendiente: 0.0016430315778467111
# Iteraciones:78 , Pendiente: 0.001478728620396665
# Iteraciones:79 , Pendiente: 0.0013308559044010158
# Iteraciones:80 , Pendiente: 0.0011977704204271117
# Iteraciones:81 , Pendiente: 0.0010779934559982242
# Iteraciones:82 , Pendiente: 0.000970194166978904
# Iteraciones:83 , Pendiente: 0.0008731747915282527
# Iteraciones:84 , Pendiente: 0.0007858573424445254
# Iteraciones:85 , Pendiente: 0.0007072716301205021
# Iteraciones:86 , Pendiente: 0.0006365444830884625
# Iteraciones:87 , Pendiente: 0.0005728900464290811
# Iteraciones:88 , Pendiente: 0.0005156010502786523
# Iteraciones:89 , Pendiente: 0.00046404095144169614
# Iteraciones:90 , Pendiente: 0.0004176368608106955
# Iteraciones:91 , Pendiente: 0.00037587317801983887
# Iteraciones:92 , Pendiente: 0.00033828586261633927
# Iteraciones:93 , Pendiente: 0.00030445727810330243
# Iteraciones:94 , Pendiente: 0.00027401155156755747
# Iteraciones:95 , Pendiente: 0.0002466103973401428
# Iteraciones:96 , Pendiente: 0.0002219493582834674
# Iteraciones:97 , Pendiente: 0.0001997544229489653
# Iteraciones:98 , Pendiente: 0.00017977898101404093
# Iteraciones:99 , Pendiente: 0.0001618010831751659
# Iteraciones:100 , Pendiente: 0.00014562097504887736
# Iteraciones:101 , Pendiente: 0.00013105887768340597
# Iteraciones:102 , Pendiente: 0.00011795299001670964
# Iteraciones:103 , Pendiente: 0.00010615769108908236
# Iteraciones:104 , Pendiente: 9.554192203423772e-05
# Iteraciones:105 , Pendiente: 8.598772987024194e-05
# Iteraciones:106 , Pendiente: 7.738895691197965e-05
# Iteraciones:107 , Pendiente: 6.965006124174652e-05
# Iteraciones:108 , Pendiente: 6.268505513293637e-05
# Iteraciones:109 , Pendiente: 5.641654963073227e-05
# Iteraciones:110 , Pendiente: 5.077489467586916e-05
# Iteraciones:111 , Pendiente: 4.569740521423953e-05
# Iteraciones:112 , Pendiente: 4.112766469722893e-05
# Iteraciones:113 , Pendiente: 3.7014898230538426e-05
# Iteraciones:114 , Pendiente: 3.331340840973542e-05
# Iteraciones:115 , Pendiente: 2.9982067570443393e-05
# Iteraciones:116 , Pendiente: 2.698386081457298e-05
# Iteraciones:117 , Pendiente: 2.4285474733992625e-05
# Iteraciones:118 , Pendiente: 2.1856927261296357e-05
# Iteraciones:119 , Pendiente: 1.967123453562586e-05
# Iteraciones:120 , Pendiente: 1.7704111082508384e-05
# Iteraciones:121 , Pendiente: 1.5933699974599453e-05
# Iteraciones:122 , Pendiente: 1.4340329977283125e-05
# Iteraciones:123 , Pendiente: 1.29062969797338e-05
# Iteraciones:124 , Pendiente: 1.1615667281827814e-05
# Iteraciones:125 , Pendiente: 1.0454100553762435e-05
# Iteraciones:126 , Pendiente: 9.408690498402671e-06
# Iteraciones:127 , Pendiente: 8.467821448658878e-06
# Iteraciones:128 , Pendiente: 7.621039303838622e-06
# Iteraciones:129 , Pendiente: 6.858935373451294e-06
# Iteraciones:130 , Pendiente: 6.173041836165893e-06
# Iteraciones:131 , Pendiente: 5.555737652628745e-06
# Iteraciones:132 , Pendiente: 5.00016388742129e-06
# Iteraciones:133 , Pendiente: 4.500147498688847e-06
# Iteraciones:134 , Pendiente: 4.050132748784274e-06
# Iteraciones:135 , Pendiente: 3.645119473869454e-06
# Iteraciones:136 , Pendiente: 3.2806075265788305e-06
# Iteraciones:137 , Pendiente: 2.9525467740168947e-06
# Iteraciones:138 , Pendiente: 2.6572920966442665e-06
# Iteraciones:139 , Pendiente: 2.39156288689768e-06
# Iteraciones:140 , Pendiente: 2.1524065981256073e-06
# Iteraciones:141 , Pendiente: 1.937165938386067e-06
# Iteraciones:142 , Pendiente: 1.743449344509382e-06
# Iteraciones:143 , Pendiente: 1.5691044100203091e-06
# Iteraciones:144 , Pendiente: 1.4121939689356937e-06
# Iteraciones:145 , Pendiente: 1.2709745720927368e-06
# Iteraciones:146 , Pendiente: 1.1438771148674405e-06
# Iteraciones:147 , Pendiente: 1.0294894033424534e-06
# Iteraciones:148 , Pendiente: 9.265404630809757e-07
# Iteraciones:149 , Pendiente: 8.338864168678418e-07
# Iteraciones:150 , Pendiente: 7.504977750983796e-07
# Iteraciones:151 , Pendiente: 6.754479975946769e-07
# Iteraciones:152 , Pendiente: 6.079031978413412e-07
# Iteraciones:153 , Pendiente: 5.471128779523144e-07
# Iteraciones:154 , Pendiente: 4.924015902298243e-07
# Iteraciones:155 , Pendiente: 4.4316143116855957e-07
# Iteraciones:156 , Pendiente: 3.9884528796901147e-07
# Iteraciones:157 , Pendiente: 3.5896075917823535e-07
# Iteraciones:158 , Pendiente: 3.2306468328874086e-07
# Iteraciones:159 , Pendiente: 2.907582148993776e-07
# Iteraciones:160 , Pendiente: 2.6168239337115485e-07
# Iteraciones:161 , Pendiente: 2.3551415401795864e-07
# Iteraciones:162 , Pendiente: 2.1196273853346853e-07
# Iteraciones:163 , Pendiente: 1.9076646468624517e-07
# Iteraciones:164 , Pendiente: 1.7168981820153963e-07
# Iteraciones:165 , Pendiente: 1.5452083640971351e-07
# Iteraciones:166 , Pendiente: 1.3906875279706995e-07
# Iteraciones:167 , Pendiente: 1.2516187759009966e-07
# Iteraciones:168 , Pendiente: 1.1264568972619069e-07
# Iteraciones:169 , Pendiente: 1.0138112067087705e-07
# Iteraciones:170 , Pendiente: 9.124300854329922e-08
# Iteraciones:171 , Pendiente: 8.21187076728881e-08
# Iteraciones:172 , Pendiente: 7.3906836933927e-08
# Iteraciones:173 , Pendiente: 6.651615331327092e-08
# Iteraciones:174 , Pendiente: 5.986453805468046e-08
# Iteraciones:175 , Pendiente: 5.3878084277540114e-08
# Iteraciones:176 , Pendiente: 4.849027585590934e-08
# Iteraciones:177 , Pendiente: 4.3641248232032725e-08
# Iteraciones:178 , Pendiente: 3.9277123392748225e-08
# Iteraciones:179 , Pendiente: 3.534941101518772e-08
# Iteraciones:180 , Pendiente: 3.1814470008610024e-08
# Iteraciones:181 , Pendiente: 2.8633022902849953e-08
# Iteraciones:182 , Pendiente: 2.5769720640892652e-08
# Iteraciones:183 , Pendiente: 2.3192748671744462e-08
# Iteraciones:184 , Pendiente: 2.0873473899511095e-08
# Iteraciones:185 , Pendiente: 1.878612649347876e-08
# Iteraciones:186 , Pendiente: 1.6907513894663038e-08
# Iteraciones:187 , Pendiente: 1.521676257793335e-08
# Iteraciones:188 , Pendiente: 1.3695086237445406e-08
# Iteraciones:189 , Pendiente: 1.2325577508801797e-08
# Iteraciones:190 , Pendiente: 1.109301967522701e-08
# Iteraciones:191 , Pendiente: 9.983717691623082e-09
# Iteraciones:192 , Pendiente: 8.985345861970626e-09
# Iteraciones:193 , Pendiente: 8.086811281896798e-09
# Iteraciones:194 , Pendiente: 7.2781301598303526e-09
# Iteraciones:195 , Pendiente: 6.550317238788393e-09
# Iteraciones:196 , Pendiente: 5.895285432214946e-09
# Iteraciones:197 , Pendiente: 5.305756784094383e-09
# Iteraciones:198 , Pendiente: 4.775181200626021e-09
# Iteraciones:199 , Pendiente: 4.2976631755044946e-09
# Iteraciones:200 , Pendiente: 3.867896952895121e-09
# Iteraciones:201 , Pendiente: 3.4811072415243825e-09
# Iteraciones:202 , Pendiente: 3.1329965901085597e-09
# Iteraciones:203 , Pendiente: 2.8196969816298588e-09
# Iteraciones:204 , Pendiente: 2.537727200772265e-09
# Iteraciones:205 , Pendiente: 2.283954420204891e-09
# Iteraciones:206 , Pendiente: 2.055558895489794e-09
# Iteraciones:207 , Pendiente: 1.8500031008818903e-09
# Iteraciones:208 , Pendiente: 1.6650028635303168e-09
# Iteraciones:209 , Pendiente: 1.498502494482677e-09
# Iteraciones:210 , Pendiente: 1.348652140135341e-09
# Iteraciones:211 , Pendiente: 1.2137869100405803e-09
# Iteraciones:212 , Pendiente: 1.0924082251597563e-09
